# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f911a275-04e5-4c44-96aa-6596708dcf1f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f911a275-04e5-4c44-96aa-6596708dcf1f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving weather.csv to weather.csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['weather.csv']))

# %%
df.head()
# Out:
#        Date/Time  Temp_C  ...  Press_kPa               Weather
# 0  1/1/2012 0:00    -1.8  ...     101.24                   Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                   Fog
# 2  1/1/2012 2:00    -1.8  ...     101.26  Freezing Drizzle,Fog
# 3  1/1/2012 3:00    -1.5  ...     101.27  Freezing Drizzle,Fog
# 4  1/1/2012 4:00    -1.5  ...     101.23                   Fog
#
# [5 rows x 8 columns]

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
df['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
df.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
df.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
df["Weather"].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Haze                                         16
# Thunderstorms,Rain Showers                   16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# # Q)Find alll the unique wind speed values in the data

# %%
df.head()
# Out:
#        Date/Time  Temp_C  ...  Press_kPa               Weather
# 0  1/1/2012 0:00    -1.8  ...     101.24                   Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                   Fog
# 2  1/1/2012 2:00    -1.8  ...     101.26  Freezing Drizzle,Fog
# 3  1/1/2012 3:00    -1.5  ...     101.27  Freezing Drizzle,Fog
# 4  1/1/2012 4:00    -1.5  ...     101.23                   Fog
#
# [5 rows x 8 columns]

# %%
df["Wind Speed_km/h"].nunique()
# Out:
# 34

# %%
df["Wind Speed_km/h"].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %% [markdown]
# # Q) Find the number of times the weather is exactly clear

# %%
df.head()
# Out:
#        Date/Time  Temp_C  ...  Press_kPa               Weather
# 0  1/1/2012 0:00    -1.8  ...     101.24                   Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                   Fog
# 2  1/1/2012 2:00    -1.8  ...     101.26  Freezing Drizzle,Fog
# 3  1/1/2012 3:00    -1.5  ...     101.27  Freezing Drizzle,Fog
# 4  1/1/2012 4:00    -1.5  ...     101.23                   Fog
#
# [5 rows x 8 columns]

# %%
df.Weather.value_counts() #value_counts
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Haze                                         16
# Thunderstorms,Rain Showers                   16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
#filtering
df[df.Weather == "Clear"]
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather
# 67      1/3/2012 19:00   -16.9  ...     101.74    Clear
# 114     1/5/2012 18:00    -7.1  ...     100.71    Clear
# 115     1/5/2012 19:00    -9.2  ...     100.80    Clear
# 116     1/5/2012 20:00    -9.8  ...     100.83    Clear
# 117     1/5/2012 21:00    -9.0  ...     100.83    Clear
# ...                ...     ...  ...        ...      ...
# 8646   12/26/2012 6:00   -13.4  ...     102.47    Clear
# 8698  12/28/2012 10:00    -6.1  ...     101.27    Clear
# 8713   12/29/2012 1:00   -11.9  ...     101.31    Clear
# 8714   12/29/2012 2:00   -11.8  ...     101.33    Clear
# 8756  12/30/2012 20:00   -13.8  ...     101.52    Clear
#
# [1326 rows x 8 columns]

# %%
#groupby
df.groupby("Weather").get_group('Clear')
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather
# 67      1/3/2012 19:00   -16.9  ...     101.74    Clear
# 114     1/5/2012 18:00    -7.1  ...     100.71    Clear
# 115     1/5/2012 19:00    -9.2  ...     100.80    Clear
# 116     1/5/2012 20:00    -9.8  ...     100.83    Clear
# 117     1/5/2012 21:00    -9.0  ...     100.83    Clear
# ...                ...     ...  ...        ...      ...
# 8646   12/26/2012 6:00   -13.4  ...     102.47    Clear
# 8698  12/28/2012 10:00    -6.1  ...     101.27    Clear
# 8713   12/29/2012 1:00   -11.9  ...     101.31    Clear
# 8714   12/29/2012 2:00   -11.8  ...     101.33    Clear
# 8756  12/30/2012 20:00   -13.8  ...     101.52    Clear
#
# [1326 rows x 8 columns]

# %% [markdown]
# # Q) find the number of times when the wind speeed was exactly 4km/h

# %%
df.head()
# Out:
#        Date/Time  Temp_C  ...  Press_kPa               Weather
# 0  1/1/2012 0:00    -1.8  ...     101.24                   Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                   Fog
# 2  1/1/2012 2:00    -1.8  ...     101.26  Freezing Drizzle,Fog
# 3  1/1/2012 3:00    -1.5  ...     101.27  Freezing Drizzle,Fog
# 4  1/1/2012 4:00    -1.5  ...     101.23                   Fog
#
# [5 rows x 8 columns]

# %%
df[df["Wind Speed_km/h"]==4.0]
# Out:
#              Date/Time  Temp_C  ...  Press_kPa       Weather
# 0        1/1/2012 0:00    -1.8  ...     101.24           Fog
# 1        1/1/2012 1:00    -1.8  ...     101.24           Fog
# 96       1/5/2012 0:00    -8.8  ...     100.32          Snow
# 101      1/5/2012 5:00    -7.0  ...     100.19          Snow
# 146      1/7/2012 2:00    -8.1  ...     100.15        Cloudy
# ...                ...     ...  ...        ...           ...
# 8768   12/31/2012 8:00    -8.6  ...     101.14  Snow Showers
# 8769   12/31/2012 9:00    -8.1  ...     101.09          Snow
# 8770  12/31/2012 10:00    -7.4  ...     101.05      Snow,Fog
# 8772  12/31/2012 12:00    -5.8  ...     100.78          Snow
# 8773  12/31/2012 13:00    -4.6  ...     100.63          Snow
#
# [474 rows x 8 columns]

# %% [markdown]
# # Q) find null values in the data

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# # Q)Rename the column name weather to wthr

# %%
df.rename(columns={"Weather":"wthr"},inplace=True)

# %%
df.head()
# Out:
#        Date/Time  Temp_C  ...  Press_kPa                  wthr
# 0  1/1/2012 0:00    -1.8  ...     101.24                   Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                   Fog
# 2  1/1/2012 2:00    -1.8  ...     101.26  Freezing Drizzle,Fog
# 3  1/1/2012 3:00    -1.5  ...     101.27  Freezing Drizzle,Fog
# 4  1/1/2012 4:00    -1.5  ...     101.23                   Fog
#
# [5 rows x 8 columns]

# %% [markdown]
# # Q) what is the mean visibility

# %%
df["Visibility_km"].mean()
# Out:
# 27.66444672131151

# %% [markdown]
# # Q) what is standard deviation of presure in this data?

# %%
df.head()
# Out:
#        Date/Time  Temp_C  ...  Press_kPa                  wthr
# 0  1/1/2012 0:00    -1.8  ...     101.24                   Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                   Fog
# 2  1/1/2012 2:00    -1.8  ...     101.26  Freezing Drizzle,Fog
# 3  1/1/2012 3:00    -1.5  ...     101.27  Freezing Drizzle,Fog
# 4  1/1/2012 4:00    -1.5  ...     101.23                   Fog
#
# [5 rows x 8 columns]

# %%
df.Press_kPa.std()
# Out:
# 0.8440047459486474

# %% [markdown]
# # Q) what is the variance of relative humidity in this data?

# %%
df["Rel Hum_%"].var()
# Out:
# 286.2485501984998

# %% [markdown]
# # Q) find all the instance when Snow was recorded.

# %%
df[df["wthr"]=="Snow"]
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  wthr
# 55       1/3/2012 7:00   -14.0  ...     100.95  Snow
# 84      1/4/2012 12:00   -13.7  ...     101.25  Snow
# 86      1/4/2012 14:00   -11.3  ...     100.97  Snow
# 87      1/4/2012 15:00   -10.2  ...     100.89  Snow
# 88      1/4/2012 16:00    -9.4  ...     100.79  Snow
# ...                ...     ...  ...        ...   ...
# 8779  12/31/2012 19:00     0.1  ...     100.13  Snow
# 8780  12/31/2012 20:00     0.2  ...     100.03  Snow
# 8781  12/31/2012 21:00    -0.5  ...      99.95  Snow
# 8782  12/31/2012 22:00    -0.2  ...      99.91  Snow
# 8783  12/31/2012 23:00     0.0  ...      99.89  Snow
#
# [390 rows x 8 columns]

# %%
df.wthr.value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Haze                                         16
# Thunderstorms,Rain Showers                   16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
df[df["wthr"].str.contains('Snow')]
# Out:
#              Date/Time  Temp_C  ...  Press_kPa          wthr
# 41      1/2/2012 17:00    -2.1  ...      99.66  Snow Showers
# 44      1/2/2012 20:00    -5.6  ...     100.07  Snow Showers
# 45      1/2/2012 21:00    -5.8  ...     100.15  Snow Showers
# 47      1/2/2012 23:00    -7.4  ...     100.27  Snow Showers
# 48       1/3/2012 0:00    -9.0  ...     100.35  Snow Showers
# ...                ...     ...  ...        ...           ...
# 8779  12/31/2012 19:00     0.1  ...     100.13          Snow
# 8780  12/31/2012 20:00     0.2  ...     100.03          Snow
# 8781  12/31/2012 21:00    -0.5  ...      99.95          Snow
# 8782  12/31/2012 22:00    -0.2  ...      99.91          Snow
# 8783  12/31/2012 23:00     0.0  ...      99.89          Snow
#
# [583 rows x 8 columns]

# %% [markdown]
# # Q) Find all the instance when wind speed is above 24 and visibility is 25.

# %%
df.head()
# Out:
#        Date/Time  Temp_C  ...  Press_kPa                  wthr
# 0  1/1/2012 0:00    -1.8  ...     101.24                   Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                   Fog
# 2  1/1/2012 2:00    -1.8  ...     101.26  Freezing Drizzle,Fog
# 3  1/1/2012 3:00    -1.5  ...     101.27  Freezing Drizzle,Fog
# 4  1/1/2012 4:00    -1.5  ...     101.23                   Fog
#
# [5 rows x 8 columns]

# %%
df[(df["Wind Speed_km/h"]>24) & (df["Visibility_km"]==25)]
# Out:
#              Date/Time  Temp_C  ...  Press_kPa           wthr
# 23      1/1/2012 23:00     5.3  ...      99.31         Cloudy
# 24       1/2/2012 0:00     5.2  ...      99.26   Rain Showers
# 25       1/2/2012 1:00     4.6  ...      99.26         Cloudy
# 26       1/2/2012 2:00     3.9  ...      99.26  Mostly Cloudy
# 27       1/2/2012 3:00     3.7  ...      99.30  Mostly Cloudy
# ...                ...     ...  ...        ...            ...
# 8705  12/28/2012 17:00    -8.6  ...     101.34   Mainly Clear
# 8753  12/30/2012 17:00   -12.1  ...     101.26   Mainly Clear
# 8755  12/30/2012 19:00   -13.4  ...     101.47   Mainly Clear
# 8759  12/30/2012 23:00   -12.1  ...     101.52  Mostly Cloudy
# 8760   12/31/2012 0:00   -11.1  ...     101.51         Cloudy
#
# [308 rows x 8 columns]

# %% [markdown]
# # Q) What is the mean value of each column against wthr

# %%
df.groupby('wthr').mean()
# Out:
#                                             Temp_C  ...   Press_kPa
# wthr                                                ...
# Clear                                     6.825716  ...  101.587443
# Cloudy                                    7.970544  ...  100.911441
# Drizzle                                   7.353659  ...  100.435366
# Drizzle,Fog                               8.067500  ...  100.786625
# Drizzle,Ice Pellets,Fog                   0.400000  ...  100.790000
# Drizzle,Snow                              1.050000  ...  100.890000
# Drizzle,Snow,Fog                          0.693333  ...   99.281333
# Fog                                       4.303333  ...  101.184067
# Freezing Drizzle                         -5.657143  ...  100.202857
# Freezing Drizzle,Fog                     -2.533333  ...  100.441667
# Freezing Drizzle,Haze                    -5.433333  ...  100.316667
# Freezing Drizzle,Snow                    -5.109091  ...  100.520909
# ...

# %%
df.rename(columns={"wthr":"weather"},inplace=True)

# %% [markdown]
# #Q) what is the minimum and maximum value of each colummn against each weather

# %%
df.groupby('weather').min()
# Out:
#                                                 Date/Time  ...  Press_kPa
# weather                                                    ...
# Clear                                      1/11/2012 1:00  ...      99.52
# Cloudy                                     1/1/2012 17:00  ...      98.39
# Drizzle                                   1/23/2012 21:00  ...      97.84
# Drizzle,Fog                               1/23/2012 20:00  ...      98.65
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00  ...     100.79
# Drizzle,Snow                             12/17/2012 15:00  ...     100.63
# Drizzle,Snow,Fog                         12/18/2012 21:00  ...      97.79
# Fog                                         1/1/2012 0:00  ...      98.31
# Freezing Drizzle                          1/13/2012 10:00  ...      98.44
# Freezing Drizzle,Fog                        1/1/2012 2:00  ...      98.74
# Freezing Drizzle,Haze                      2/1/2012 11:00  ...     100.28
# ...

# %%
df.groupby('weather').max()
# Out:
#                                                 Date/Time  ...  Press_kPa
# weather                                                    ...
# Clear                                       9/9/2012 5:00  ...     103.63
# Cloudy                                     9/9/2012 23:00  ...     103.65
# Drizzle                                    9/30/2012 3:00  ...     101.56
# Drizzle,Fog                                9/30/2012 2:00  ...     102.07
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00  ...     100.79
# Drizzle,Snow                             12/19/2012 18:00  ...     101.15
# Drizzle,Snow,Fog                          12/22/2012 3:00  ...     100.15
# Fog                                        9/22/2012 0:00  ...     103.04
# Freezing Drizzle                            2/1/2012 5:00  ...     101.02
# Freezing Drizzle,Fog                      12/10/2012 5:00  ...     101.27
# Freezing Drizzle,Haze                      2/1/2012 13:00  ...     100.36
# ...

# %% [markdown]
# #Q) show all the record where Weather Condition is fog.

# %%
df[df["weather"]=='Fog']
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  weather
# 0        1/1/2012 0:00    -1.8  ...     101.24      Fog
# 1        1/1/2012 1:00    -1.8  ...     101.24      Fog
# 4        1/1/2012 4:00    -1.5  ...     101.23      Fog
# 5        1/1/2012 5:00    -1.4  ...     101.27      Fog
# 6        1/1/2012 6:00    -1.5  ...     101.29      Fog
# ...                ...     ...  ...        ...      ...
# 8716   12/29/2012 4:00   -16.0  ...     101.25      Fog
# 8717   12/29/2012 5:00   -14.8  ...     101.25      Fog
# 8718   12/29/2012 6:00   -13.8  ...     101.25      Fog
# 8719   12/29/2012 7:00   -14.8  ...     101.22      Fog
# 8722  12/29/2012 10:00   -12.0  ...     101.15      Fog
#
# [150 rows x 8 columns]

# %% [markdown]
# #Q) Find all the instance when weather is clear or visibility is above 40

# %%
df[(df.weather=="Clear") | (df.Visibility_km>40)]
# Out:
#              Date/Time  Temp_C  ...  Press_kPa        weather
# 67      1/3/2012 19:00   -16.9  ...     101.74          Clear
# 106     1/5/2012 10:00    -6.0  ...     100.45   Mainly Clear
# 107     1/5/2012 11:00    -5.6  ...     100.41   Mainly Clear
# 108     1/5/2012 12:00    -4.7  ...     100.38   Mainly Clear
# 109     1/5/2012 13:00    -4.4  ...     100.40   Mainly Clear
# ...                ...     ...  ...        ...            ...
# 8749  12/30/2012 13:00   -12.4  ...     100.92  Mostly Cloudy
# 8750  12/30/2012 14:00   -11.8  ...     100.96   Mainly Clear
# 8751  12/30/2012 15:00   -11.3  ...     101.05   Mainly Clear
# 8752  12/30/2012 16:00   -11.4  ...     101.15   Mainly Clear
# 8756  12/30/2012 20:00   -13.8  ...     101.52          Clear
#
# [3027 rows x 8 columns]

# %% [markdown]
# # Q) Find all instances when:
#      A. weather is clear and relative humidity is greater than 50
#      or
#      B. visibility is above 40

# %%
df.head()
# Out:
#        Date/Time  Temp_C  ...  Press_kPa               weather
# 0  1/1/2012 0:00    -1.8  ...     101.24                   Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                   Fog
# 2  1/1/2012 2:00    -1.8  ...     101.26  Freezing Drizzle,Fog
# 3  1/1/2012 3:00    -1.5  ...     101.27  Freezing Drizzle,Fog
# 4  1/1/2012 4:00    -1.5  ...     101.23                   Fog
#
# [5 rows x 8 columns]

# %%
df[(df['weather']=="Clear") &(df['Rel Hum_%']>50)|(df['Visibility_km']>40)]
# Out:
#              Date/Time  Temp_C  ...  Press_kPa        weather
# 106     1/5/2012 10:00    -6.0  ...     100.45   Mainly Clear
# 107     1/5/2012 11:00    -5.6  ...     100.41   Mainly Clear
# 108     1/5/2012 12:00    -4.7  ...     100.38   Mainly Clear
# 109     1/5/2012 13:00    -4.4  ...     100.40   Mainly Clear
# 110     1/5/2012 14:00    -5.1  ...     100.46   Mainly Clear
# ...                ...     ...  ...        ...            ...
# 8749  12/30/2012 13:00   -12.4  ...     100.92  Mostly Cloudy
# 8750  12/30/2012 14:00   -11.8  ...     100.96   Mainly Clear
# 8751  12/30/2012 15:00   -11.3  ...     101.05   Mainly Clear
# 8752  12/30/2012 16:00   -11.4  ...     101.15   Mainly Clear
# 8756  12/30/2012 20:00   -13.8  ...     101.52          Clear
#
# [2921 rows x 8 columns]
